# %%
import matplotlib.pyplot as plt
import numpy as np


# System 2 with optimal control
u_traj = [
    11.08501,
    72.84027,
    58.59781,
    46.82954,
    31.83621,
    21.54742,
    13.96736,
    9.01514,
    5.73690,
    3.64103,
    2.29915,
    1.44977,
    0.91244,
    0.57386,
    0.36066,
    0.22659,
    0.14232,
    0.08938,
    0.05612,
    0.03524,
    0.02212,
    0.01389,
    0.00872
]

x_norm_traj = [
    106.74474,
    121.66030,
    89.38131,
    69.90257,
    46.50569,
    31.36249,
    20.19128,
    13.01376,
    8.26164,
    5.23988,
    3.30580,
    2.08387,
    1.31107,
    0.82446,
    0.51808,
    0.32547,
    0.20441,
    0.12837,
    0.08060,
    0.05061,
    0.03177,
    0.01995,
    0.01252,
    0.00786
]

plt.plot(u_traj, label='system B: control input')
plt.plot(x_norm_traj, label='system B: norm of state')
plt.legend()

# %%
# System 3
xc_norm_traj = [
    9.35414,
    4.14578,
    3.18689,
    1.62380,
    1.05974,
    0.55792,
    0.33603,
    0.17794,
    0.10242,
    0.05415,
    0.03030,
    0.01596,
    0.00876
]
xd_norm_traj = [
    9.23309,
    2.20794,
    1.44698,
    0.66368,
    0.36896,
    0.23729,
    0.14981,
    0.10596,
    0.07206,
    0.05122,
    0.03564,
    0.02521,
    0.01767,
    0.01247,
    0.00876
]
plt.plot(xc_norm_traj, label='system C: norm of state')
plt.plot(xd_norm_traj, label='system D: norm of state')
plt.legend()
